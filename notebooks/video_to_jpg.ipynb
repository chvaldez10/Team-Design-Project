# %% [markdown]
# # DI Pre Processing
# Converts a video into png files.
# <br>
# <br>
# Usage:
# 1) Run notebook
# 2) Enter drive where video files are stored
# <br>
# <br>
#
# Notes:
# 1) Needs JSON files that contains metadata
# 2) Update root directory
# <br>
# <br>
# ![UofC logo](./pictures/uofc_logo-black.jpg)

# %%
#import libraries
import os
import cv2
import json
import pandas as pd
import numpy as np
from pathlib import Path
from timeit import default_timer as timer
from typing import List
import psutil
import traceback

# %%
# make sure to update path
user_drive = input("Enter user drive: ").upper()
video_path = f"{user_drive}:/DI_centre_structured"
input(f"Is this the right directory - {video_path}?")
# Out:
# ''

# %%
VIDEO_CHARACTERISTICS = {
    "With Blankets" : "WB",
    "B" : "WB",
    "Without Blankets" : "WOB",
    "WOB": "WOB",
    "3 Meters" : "3m",
    "2 Meters" : "2m",
    "Hold Breath" : "HB",
    "Hold Breathe" : "HB",
    "H" : "HB",
    "Relaxed" : "rel",
    "R": "rel",
}

# for testing
FRAME_LIMIT = 100

# limit for storage
MINIMUM_FREE_SPACE_GB = 75

# %%
repo_dir = os.getcwd()
json_dir = repo_dir + "/records/JSON"
log_dir = repo_dir + "/records/logs"

# %%
def create_patient_video_id(patient_data: dict, video_count: int) -> str:
    """
    Creates a unique ID for a patient video scenario.

    Parameters:
    patient_data (dict): Dictionary containing patient information.
    video_count (int): The count of videos for the patient.

    Returns:
    str: A unique ID string for the video.
    """
    alias = patient_data.get("alias", "Unknown")
    blanket = VIDEO_CHARACTERISTICS.get(patient_data.get("blanket", ""), "?")
    distance = VIDEO_CHARACTERISTICS.get(patient_data.get("distance", "").title(), "?")
    breathing = VIDEO_CHARACTERISTICS.get(patient_data.get("breathing", ""), "?")

    return f"{alias}_{video_count}-{distance}-{blanket}-{breathing}"

# %%
def set_folder(save_folder: str) -> None:
    """
    Ensures the specified folder exists and is empty.
    If the folder doesn't exist, it is created. If it exists, its contents are removed.

    Args:
    save_folder (str): The path to the folder.
    """
    folder_path = Path(save_folder)
    if not folder_path.is_dir():
        folder_path.mkdir(parents=True, exist_ok=True)
    else:
        try:
            for file_name in folder_path.iterdir():
                if file_name.is_file():
                    file_name.unlink()
        except OSError as e:
            print(f"Error: {e}")

# %%
class NotEnoughFreeSpace(Exception):
    """Exception raised when there is not enough free space on the drive."""
    pass

# It's good practice to define constants like this at the module level.
MINIMUM_FREE_SPACE_GB = 75

def get_drive_storage(user_drive: str) -> dict:
    """
    Retrieves the storage information for a given drive.

    Parameters:
    user_drive (str): The drive letter to check.

    Returns:
    dict: A dictionary with the drive's total, used, and free space in GB.

    Raises:
    FileNotFoundError: If the specified drive does not exist.
    """
    try:
        drive_usage = psutil.disk_usage(user_drive + ":\\")
        # Convert bytes to GB
        return {
            'drive_letter': user_drive,
            'total_space_GB': drive_usage.total / (1024**3),
            'used_space_GB': drive_usage.used / (1024**3),
            'free_space_GB': drive_usage.free / (1024**3),
        }
    except FileNotFoundError:
        raise FileNotFoundError(f"Drive {user_drive} not found.")

def check_drive_usage(user_drive: str):
    """
    Checks if the free space on the drive is above a minimum threshold.

    Parameters:
    user_drive (str): The drive letter to check.

    Raises:
    NotEnoughFreeSpace: If the free space on the drive is below the minimum threshold.
    """
    drive_info = get_drive_storage(user_drive)

    if drive_info["free_space_GB"] < MINIMUM_FREE_SPACE_GB:
        raise NotEnoughFreeSpace(f"Not enough free space on Drive {user_drive}. Minimum {MINIMUM_FREE_SPACE_GB} GB required.")

# %%
def save_frame(video, frame, frame_frequency, counters, patient_id, folder):
    """
    Saves a given frame to the specified folder, updating counters accordingly.
    """
    for _ in range(frame_frequency.get(counters['pick'])):
        frame_name = f"{patient_id}_{counters['save']}.png"
        cv2.imwrite(os.path.join(folder, frame_name), frame)
        counters['save'] += 1

def update_counters(counters, vid_fps):
    """
    Updates the frame processing counters.
    """
    counters['pick'] += 1
    counters['true'] += 1
    if counters['pick'] == vid_fps:
        counters['set'] += 1
        counters['pick'] = 0

def validate_frame_count(actual_count, expected_count):
    """
    Validates if the actual frame count matches the expected frame count.
    """
    if actual_count != expected_count:
        raise ValueError(f"Expected {expected_count} frames, but got {actual_count} frames")

# %%
def run_video_to_frame(video_path: str, save_folder: str, frame_frequency: dict, new_fps: int, patient_id: str, debug_mode:bool) -> list[int]:
    """
    Converts a video into frames based on specified frequencies and saves them to a folder.

    Args:
    video_path (str): Path to the video file.
    save_folder (str): Folder to save the extracted frames.
    frame_frequency (dict): Frequency of frames to extract.
    new_fps (int): Target frames per second.
    patient_id (str): ID of the patient, used in naming frames.

    Returns:
    list[int]: List containing number of sets processed, frames saved, and true frames processed.
    """
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        raise IOError(f"Cannot open video file at {video_path}")

    # Extract video metadata
    vid_fps = int(video.get(cv2.CAP_PROP_FPS))
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    video_duration = frame_count // vid_fps

    # Prepare frame list and variables
    frames_to_pick = list(frame_frequency.keys())
    expected_frame_count = new_fps * video_duration
    frame_counters = {'pick': 0, 'save': 0, 'set': 0, 'true': 0}

    # Print initial processing information
    print(f"\nSaving frames to: {save_folder}\nPicking frames: {frames_to_pick} per set\nExpected number of frames: {expected_frame_count} ({new_fps}FPS * {video_duration}s).")

    # Ensure save folder is ready
    set_folder(save_folder)

    # Process video
    start_time = timer()
    while frame_counters['set'] < video_duration:
        success, frame = video.read()
        if not success:
            break

        if frame_counters['pick'] in frames_to_pick:
            save_frame(video, frame, frame_frequency, frame_counters, patient_id, save_folder)

        update_counters(frame_counters, vid_fps)

        # for testing
        if frame_counters['true'] > FRAME_LIMIT and debug_mode:
            print(f"\nLimit set to {FRAME_LIMIT} frames for testing purposes.")
            break

    video.release()

    # Post-processing validation and timing
    end_time = timer()
    validate_frame_count(frame_counters['save'], expected_frame_count)
    print(f"\nDone in {end_time - start_time} seconds.")

    return [frame_counters[key] for key in ['set', 'save', 'true']]

# %%
def get_video_frame_paths(local_path: str, level: str) -> List[str]:
    """
    Constructs and returns paths related to video frames.

    Parameters:
    local_path (str): The local file path of the video.
    level (str): The detail level for the frames.

    Returns:
    List[str]: A list containing the folder path for frames and the video folder path.
    """
    video_folder, video_filename_with_ext = os.path.split(local_path)
    video_filename = os.path.splitext(video_filename_with_ext)[0]
    folder_path = os.path.join(video_folder, f"frames_{video_filename}_{level}")
    return [folder_path, video_folder]

# %%
def resample_frames(old_fps: int, new_fps: int, start: int) -> List[int]:
    """
    Resamples the number of frames from an old frame rate to a new frame rate. 
    This function can handle both upsampling and downsampling.

    Parameters:
    old_fps (int): The original frames per second.
    new_fps (int): The new frames per second to resample to.
    start (int): The starting frame index.

    Returns:
    List[int]: A list of frame indices after resampling.

    Raises:
    ValueError: If old_fps or new_fps are non-positive integers.
    """
    if old_fps <= 0 or new_fps <= 0:
        raise ValueError("old_fps and new_fps must be positive integers.")

    original_frame_indices = np.arange(start, old_fps, dtype=int)
    interpolated_frame_positions = np.linspace(start, old_fps - 1, new_fps)
    nearest_frame_indices = np.round(interpolated_frame_positions).astype(int)
    resampled_frame_indices = np.take(original_frame_indices, nearest_frame_indices, mode='wrap')

    return resampled_frame_indices.tolist()

# %%
def is_png_corrupted(file_path: str) -> bool:
    """
    Checks if a PNG file is corrupted.

    Parameters:
    file_path (str): Path to the PNG file.

    Returns:
    bool: True if the file is corrupted, False otherwise.
    """
    try:
        image = cv2.imread(file_path, cv2.IMREAD_UNCHANGED)
        return image is None
    except Exception:
        return True

def find_corrupted_png_files(folder_path: str) -> list:
    """
    Finds all corrupted PNG files in a folder.

    Parameters:
    folder_path (str): Path to the folder to search.

    Returns:
    list: A list of paths to corrupted PNG files.
    """
    corrupted_files = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(".png"):
                file_path = os.path.join(root, file)
                if is_png_corrupted(file_path):
                    corrupted_files.append(file_path)
    
    return corrupted_files

def report_corrupted_files(corrupted_files: list):
    """
    Prints the paths of corrupted files.

    Parameters:
    corrupted_files (list): A list of paths to corrupted files.
    """
    if corrupted_files:
        print("Corrupted PNG files found:")
        for file_path in corrupted_files:
            print(file_path)

# %%
def process_patient(patient_info, level, new_fps, user_drive, visited_folders):
    """
    Processes the video-to-frame conversion for a single patient.
    
    Args:
    - patient_info (dict): Dictionary containing patient's information.
    - level (str): The level of detail required for the frame paths.
    - new_fps (int): The new frames per second to resample the video.
    - user_drive (str): The drive to check for available storage.
    - visited_folders (dict): A dictionary to keep track of visited folders.

    Returns:
    - str: The path to the folder containing the frames.
    """
    video_path = patient_info["local path"]
    old_fps = int(patient_info["old fps"])

    frames_folder, video_folder = get_video_frame_paths(video_path, level)
    update_visited_folders(visited_folders, video_folder)

    frames_to_pick = resample_and_validate_frames(old_fps, new_fps)
    patient_id = create_patient_video_id(patient_info, visited_folders[video_folder])
    process_video_frames(video_path, frames_folder, frames_to_pick, new_fps, patient_id)
    check_drive_usage(user_drive)

    return frames_folder

def update_visited_folders(visited_folders, video_folder):
    """
    Updates the count of processed videos for each folder.

    Args:
    - visited_folders (dict): Dictionary to keep track of visited folders.
    - video_folder (str): The current video folder being processed.

    Modifies:
    - visited_folders: Increments the count of the current video folder.
    """
    visited_folders[video_folder] = visited_folders.get(video_folder, 0) + 1

def resample_and_validate_frames(old_fps, new_fps):
    """
    Resamples frames based on old and new fps, and validates the frame count.

    Args:
    - old_fps (int): The original frames per second of the video.
    - new_fps (int): The new frames per second to resample the video to.

    Returns:
    - list: List of frames to pick.

    Raises:
    - ValueError: If the number of frames to pick does not equal new fps.
    """
    frames_to_pick = resample_frames(old_fps, new_fps, 1)
    if len(frames_to_pick) != new_fps:
        raise ValueError("Number of frames to pick is not equal to new fps")
    return frames_to_pick

def process_video_frames(video_path, frames_folder, frames_to_pick, new_fps, patient_id):
    """
    Converts a video to frames based on specified parameters.

    Args:
    - video_path (str): Path to the video file.
    - frames_folder (str): Path to the folder to save the frames.
    - frames_to_pick (list): List of frames to pick from the video.
    - new_fps (int): The new frames per second.
    - patient_id (str): The patient's identifier.

    Prints:
    - Information about the frame processing.
    """
    frame_frequency = pd.Index(frames_to_pick, name="frames").value_counts()
    set_counter, save_counter, true_frames = run_video_to_frame(video_path, frames_folder, frame_frequency, new_fps, patient_id, False)
    print(f"\nSet counter: {set_counter}, save counter: {save_counter}, frame counter: {true_frames}\n\n"+ "-"*50)
    find_corrupted_png_files(frames_folder)

def convert_video_to_frame(all_patients: dict, level: str, new_fps: int, user_drive: str) -> list[str]:
    """
    Converts videos of multiple patients to frames.

    Args:
    - all_patients (dict): A dictionary of all patients and their video information.
    - level (str): The level of detail required for frame paths.
    - new_fps (int): The new frames per second to resample the videos.
    - user_drive (str): The drive to check for available storage.

    Returns:
    - list[str]: A list of paths to folders containing frames for each patient.

    Note:
    - This function stops after processing the first patient. Remove 'break' to process all.
    """
    visited_folders = {}
    video_folder_list = []

    for json_index, patient_info in all_patients.items():
        try:
            frames_folder = process_patient(patient_info, level, new_fps, user_drive, visited_folders)
            video_folder_list.append(frames_folder)
        except Exception as e:
            traceback.print_exc()
            print(f'''{type(e)}: {e} for video {patient_info["filename"]}''')
        # break  

    return visited_folders

# %%
def load_json(json_dir: str, filename: str) -> dict:
    # Remove leading slash if present in filename
    if filename.startswith("/"):
        filename = filename[1:]

    full_path = os.path.join(json_dir, filename)

    try:
        with open(full_path, "r") as json_data:
            return json.load(json_data)
    except FileNotFoundError:
        print(f"Error: The file {full_path} does not exist.")
        return {}
    except json.JSONDecodeError:
        print(f"Error: The file {full_path} is not a valid JSON.")
        return {}

# %%
def save_paths_to_log(list_of_paths: list, log_filename: str) -> None:
    try:
        with open(log_filename, "w") as log_data:
            for folder in list_of_paths:
                log_data.write(f"{folder}\n")
    except IOError as e:
        print(f"An error occurred while writing to {log_filename}: {e}")

# %% [markdown]
# ## Video to frames (stage 3)
#
# Based on the desired fps, turn videos into frames

# %%
""" local vars"""

rgb_fps = {
    "5_fps": 5,
}

thermal_fps = {
}

# %%
""" load JSON files """

metadata_rgb = load_json(json_dir, "/rgb_complete.json")
# metadata_thermal = load_json(json_dir, "/thermal_complete.json")

# %%
""" log files to store exported frames """

rgb_logfile_prefix = log_dir + "/exported/rgb-exported"
thermal_logfile_prefix = log_dir + "/exported/thermal-exported"

# %%
""" convert video to png (rgb) """

for level, new_fps in rgb_fps.items():
    print(f"\nAdjusting FPS to {new_fps}\n" + "="*50)
    rgb_logfile = rgb_logfile_prefix + "-" + level + ".log"
    visited_folders = convert_video_to_frame(metadata_rgb, level, new_fps, user_drive)
# Out:
# Adjusting FPS to 5
# ==================================================
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\With Blankets\Hold Breath\frames_Arun2_5_fps
# Picking frames: [2, 9, 15, 22, 1] per set
# Expected number of frames: 370 (5FPS * 74s).
#
# Done in 49.58967090000078 seconds.
#
# Set counter: 74, save counter: 370, frame counter: 2146
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\With Blankets\Hold Breath\frames_Arun2_2_5_fps
# Picking frames: [2, 9, 15, 22, 1] per set
# Expected number of frames: 195 (5FPS * 39s).
#
# Done in 23.028039000000717 seconds.
#
# Set counter: 39, save counter: 195, frame counter: 1131
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\With Blankets\Relaxed\frames_Arun2_5_fps
# Picking frames: [2, 6, 10, 14, 1] per set
# Expected number of frames: 35 (5FPS * 7s).
#
# Done in 2.8159732000021904 seconds.
#
# Set counter: 7, save counter: 35, frame counter: 126
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\With Blankets\Relaxed\frames_Arun2_2_5_fps
# Picking frames: [2, 9, 15, 22, 1] per set
# Expected number of frames: 195 (5FPS * 39s).
#
# Done in 19.84780630000023 seconds.
#
# Set counter: 39, save counter: 195, frame counter: 1131
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\Without Blankets\Hold Breath\frames_short_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 180 (5FPS * 36s).
#
# Done in 18.474685599998338 seconds.
#
# Set counter: 36, save counter: 180, frame counter: 1764
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\2 Meters\Without Blankets\Relaxed\frames_relax 2meter short_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 365 (5FPS * 73s).
#
# Done in 38.99747930000012 seconds.
#
# Set counter: 73, save counter: 365, frame counter: 3869
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\3 Meters\With Blankets\Hold Breath\frames_Arun3_5_fps
# Picking frames: [2, 11, 19, 27, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 17.391250300002866 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1332
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\3 Meters\With Blankets\Relaxed\frames_Arun3_5_fps
# Picking frames: [2, 10, 17, 25, 1] per set
# Expected number of frames: 210 (5FPS * 42s).
#
# Done in 19.690174999999726 seconds.
#
# Set counter: 42, save counter: 210, frame counter: 1386
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\3 Meters\Without Blankets\Hold Breath\frames_Arun3_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 13.985921000003145 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1430
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Arun\3 Meters\Without Blankets\Relaxed\frames_Arun3_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 13.912733900000603 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1430
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\2 Meters\With Blankets\Hold Breath\frames_Daniel HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 245 (5FPS * 49s).
#
# Done in 26.35494800000015 seconds.
#
# Set counter: 49, save counter: 245, frame counter: 2548
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\2 Meters\With Blankets\Relaxed\frames_Daniel_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 305 (5FPS * 61s).
#
# Done in 32.25900279999769 seconds.
#
# Set counter: 61, save counter: 305, frame counter: 3111
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\2 Meters\Without Blankets\Hold Breath\frames_Daniel HB_5_fps
# Picking frames: [2, 12, 21, 31, 1] per set
# Expected number of frames: 310 (5FPS * 62s).
#
# Done in 29.35769309999887 seconds.
#
# Set counter: 62, save counter: 310, frame counter: 2542
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\2 Meters\Without Blankets\Relaxed\frames_Daniel_5_fps
# Picking frames: [2, 12, 22, 32, 1] per set
# Expected number of frames: 320 (5FPS * 64s).
#
# Done in 30.636863899999298 seconds.
#
# Set counter: 64, save counter: 320, frame counter: 2688
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\3 Meters\With Blankets\Hold Breath\frames_Daniel HB_5_fps
# Picking frames: [2, 13, 23, 34, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 13.342587399998592 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1170
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\3 Meters\With Blankets\Relaxed\frames_Daniel_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 145 (5FPS * 29s).
#
# Done in 14.773353000000498 seconds.
#
# Set counter: 29, save counter: 145, frame counter: 1247
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\3 Meters\Without Blankets\Hold Breath\frames_Daniel HB_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 125 (5FPS * 25s).
#
# Done in 13.61270499999955 seconds.
#
# Set counter: 25, save counter: 125, frame counter: 1375
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Daniel\3 Meters\Without Blankets\Relaxed\frames_Daniel_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 12.948435900001641 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1296
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\2 Meters\With Blankets\Hold Breath\frames_Eddy HB_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 290 (5FPS * 58s).
#
# Done in 29.972969399997965 seconds.
#
# Set counter: 58, save counter: 290, frame counter: 2494
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\2 Meters\With Blankets\Relaxed\frames_Eddy_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 290 (5FPS * 58s).
#
# Done in 30.20250760000272 seconds.
#
# Set counter: 58, save counter: 290, frame counter: 2494
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\2 Meters\Without Blankets\Hold Breath\frames_Eddy HB_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 240 (5FPS * 48s).
#
# Done in 25.62492900000143 seconds.
#
# Set counter: 48, save counter: 240, frame counter: 2640
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\2 Meters\Without Blankets\Relaxed\frames_Eddy_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 245 (5FPS * 49s).
#
# Done in 25.6138323999985 seconds.
#
# Set counter: 49, save counter: 245, frame counter: 2646
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\3 Meters\With Blankets\Hold Breath\frames_Eddy HB_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.042122200000449 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1458
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\3 Meters\With Blankets\Relaxed\frames_Eddy_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 145 (5FPS * 29s).
#
# Done in 15.0092896999995 seconds.
#
# Set counter: 29, save counter: 145, frame counter: 1508
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\3 Meters\Without Blankets\Hold Breath\frames_Eddy HB_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 145 (5FPS * 29s).
#
# Done in 14.604259499999898 seconds.
#
# Set counter: 29, save counter: 145, frame counter: 1479
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Eddy\3 Meters\Without Blankets\Relaxed\frames_Eddy_5_fps
# Picking frames: [2, 13, 25, 36, 1] per set
# Expected number of frames: 155 (5FPS * 31s).
#
# Done in 15.251789400001144 seconds.
#
# Set counter: 31, save counter: 155, frame counter: 1457
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\2 Meters\With Blankets\Hold Breath\frames_Farooq_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 155 (5FPS * 31s).
#
# Done in 15.761950400003116 seconds.
#
# Set counter: 31, save counter: 155, frame counter: 1643
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\2 Meters\With Blankets\Relaxed\frames_Farooq_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.059512700001505 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1428
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\2 Meters\Without Blankets\Hold Breath\frames_Farooq HB_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 150 (5FPS * 30s).
#
# Done in 15.12275420000151 seconds.
#
# Set counter: 30, save counter: 150, frame counter: 1470
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\2 Meters\Without Blankets\Relaxed\frames_Farooq_5_fps
# Picking frames: [2, 13, 25, 36, 1] per set
# Expected number of frames: 385 (5FPS * 77s).
#
# Done in 38.80442100000073 seconds.
#
# Set counter: 77, save counter: 385, frame counter: 3619
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\3 Meters\With Blankets\Hold Breath\frames_Farooq HB_5_fps
# Picking frames: [2, 12, 21, 31, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 17.610928199999762 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1517
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\3 Meters\With Blankets\Relaxed\frames_Farooq_5_fps
# Picking frames: [2, 12, 22, 32, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 18.005315400001564 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1554
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\3 Meters\Without Blankets\Hold Breath\frames_Farooq HB_5_fps
# Picking frames: [2, 11, 21, 31, 1] per set
# Expected number of frames: 230 (5FPS * 46s).
#
# Done in 21.391501800000697 seconds.
#
# Set counter: 46, save counter: 230, frame counter: 1840
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Farooq\3 Meters\Without Blankets\Relaxed\frames_Farooq_5_fps
# Picking frames: [2, 12, 22, 32, 1] per set
# Expected number of frames: 380 (5FPS * 76s).
#
# Done in 35.73073379999914 seconds.
#
# Set counter: 76, save counter: 380, frame counter: 3192
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank\2 Meters\With Blankets\Hold Breath\frames_Frank HB_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 16.499906900000497 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1813
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank\2 Meters\With Blankets\Relaxed\frames_Frank_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 195 (5FPS * 39s).
#
# Done in 17.982620500002668 seconds.
#
# Set counter: 39, save counter: 195, frame counter: 2067
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank\2 Meters\Without Blankets\Hold Breath\frames_Frank HB_5_fps
# Picking frames: [2, 13, 25, 36, 1] per set
# Expected number of frames: 230 (5FPS * 46s).
#
# Done in 18.80638369999724 seconds.
#
# Set counter: 46, save counter: 230, frame counter: 2162
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank\2 Meters\Without Blankets\Relaxed\frames_Frank_5_fps
# Picking frames: [2, 13, 25, 36, 1] per set
# Expected number of frames: 200 (5FPS * 40s).
#
# Done in 16.416850099998555 seconds.
#
# Set counter: 40, save counter: 200, frame counter: 1880
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\With Blankets\Hold Breath\frames_Frank2 HB_5_fps
# Picking frames: [2, 15, 29, 43, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 13.917053100001795 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1512
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\With Blankets\Hold Breath\frames_Frank3 HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.095643900000141 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1404
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\With Blankets\Hold Breath\frames_Frank4 HB_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 13.857391900000948 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1377
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\With Blankets\Relaxed\frames_Frank2_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 13.931076299999404 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1458
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\Without Blankets\Hold Breath\frames_Frank2 HB_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.428396199997223 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1512
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Frank2\3 Meters\Without Blankets\Relaxed\frames_Frank2_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 155 (5FPS * 31s).
#
# Done in 16.069413799999893 seconds.
#
# Set counter: 31, save counter: 155, frame counter: 1705
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\2 Meters\With Blankets\Hold Breath\frames_Illia HB_5_fps
# Picking frames: [2, 13, 24, 35, 1] per set
# Expected number of frames: 215 (5FPS * 43s).
#
# Done in 19.867007099997863 seconds.
#
# Set counter: 43, save counter: 215, frame counter: 1978
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\2 Meters\With Blankets\Relaxed\frames_Illia_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 260 (5FPS * 52s).
#
# Done in 24.007695200001763 seconds.
#
# Set counter: 52, save counter: 260, frame counter: 2288
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\2 Meters\Without Blankets\Hold Breath\frames_Illia HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 205 (5FPS * 41s).
#
# Done in 18.798353199999838 seconds.
#
# Set counter: 41, save counter: 205, frame counter: 2132
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\2 Meters\Without Blankets\Relaxed\frames_Illia_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 245 (5FPS * 49s).
#
# Done in 22.396490099999937 seconds.
#
# Set counter: 49, save counter: 245, frame counter: 2401
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\With Blankets\Hold Breath\frames_Illia HB_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 415 (5FPS * 83s).
#
# Done in 41.86950799999977 seconds.
#
# Set counter: 83, save counter: 415, frame counter: 4067
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\With Blankets\Hold Breath\frames_Illia HB2_5_fps
# Picking frames: [2, 13, 25, 37, 1] per set
# Expected number of frames: 410 (5FPS * 82s).
#
# Done in 40.55818740000177 seconds.
#
# Set counter: 82, save counter: 410, frame counter: 3936
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\With Blankets\Relaxed\frames_Illia_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 285 (5FPS * 57s).
#
# Done in 27.909370400000626 seconds.
#
# Set counter: 57, save counter: 285, frame counter: 2793
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\Without Blankets\Hold Breath\frames_Illia HB_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 265 (5FPS * 53s).
#
# Done in 24.98422389999905 seconds.
#
# Set counter: 53, save counter: 265, frame counter: 2279
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\Without Blankets\Hold Breath\frames_Illia HB1_5_fps
# Picking frames: [2, 13, 23, 34, 1] per set
# Expected number of frames: 190 (5FPS * 38s).
#
# Done in 17.868349000000308 seconds.
#
# Set counter: 38, save counter: 190, frame counter: 1710
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia\3 Meters\Without Blankets\Relaxed\frames_Illia_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 355 (5FPS * 71s).
#
# Done in 35.32355060000191 seconds.
#
# Set counter: 71, save counter: 355, frame counter: 3053
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\2 Meters\With Blankets\Hold Breath\frames_Illia2 HB_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.962041099999624 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1484
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\2 Meters\With Blankets\Relaxed\frames_Illia2_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 165 (5FPS * 33s).
#
# Done in 17.339277799997944 seconds.
#
# Set counter: 33, save counter: 165, frame counter: 1650
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\2 Meters\Without Blankets\Hold Breath\frames_Iliia2 HB_5_fps
# Picking frames: [2, 13, 24, 35, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.087687899998855 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1288
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\2 Meters\Without Blankets\Hold Breath\frames_Iliia3 HB_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 810 (5FPS * 162s).
#
# Done in 85.31996689999869 seconds.
#
# Set counter: 162, save counter: 810, frame counter: 8100
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\2 Meters\Without Blankets\Relaxed\frames_Illia2_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 265 (5FPS * 53s).
#
# Done in 26.090421500000957 seconds.
#
# Set counter: 53, save counter: 265, frame counter: 2332
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\3 Meters\With Blankets\Hold Breath\frames_Illia4 HB_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 150 (5FPS * 30s).
#
# Done in 16.650228399998014 seconds.
#
# Set counter: 30, save counter: 150, frame counter: 1620
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Illia2\3 Meters\With Blankets\Relaxed\frames_Illia4_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 14.174432300002081 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1404
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\2 Meters\With Blankets\Hold Breath\frames_Jay HB_5_fps
# Picking frames: [2, 12, 22, 32, 1] per set
# Expected number of frames: 200 (5FPS * 40s).
#
# Done in 18.882653700002265 seconds.
#
# Set counter: 40, save counter: 200, frame counter: 1680
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\2 Meters\With Blankets\Relaxed\frames_Jay_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 18.048025300002337 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1591
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\2 Meters\Without Blankets\Hold Breath\frames_Jay HB_5_fps
# Picking frames: [2, 13, 25, 37, 1] per set
# Expected number of frames: 230 (5FPS * 46s).
#
# Done in 22.37940609999714 seconds.
#
# Set counter: 46, save counter: 230, frame counter: 2208
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\2 Meters\Without Blankets\Relaxed\frames_Jay_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 155 (5FPS * 31s).
#
# Done in 15.004333400000178 seconds.
#
# Set counter: 31, save counter: 155, frame counter: 1674
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\3 Meters\With Blankets\Hold Breath\frames_Jay HB_5_fps
# Picking frames: [2, 13, 23, 34, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 18.901172199999564 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1665
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\3 Meters\With Blankets\Relaxed\frames_Jay_5_fps
# Picking frames: [2, 13, 23, 34, 1] per set
# Expected number of frames: 175 (5FPS * 35s).
#
# Done in 17.763642800000525 seconds.
#
# Set counter: 35, save counter: 175, frame counter: 1575
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\3 Meters\Without Blankets\Hold Breath\frames_Jay HB_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 210 (5FPS * 42s).
#
# Done in 20.37812099999792 seconds.
#
# Set counter: 42, save counter: 210, frame counter: 1806
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Jay\3 Meters\Without Blankets\Relaxed\frames_Jay_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 200 (5FPS * 40s).
#
# Done in 19.293868500000826 seconds.
#
# Set counter: 40, save counter: 200, frame counter: 1760
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\2 Meters\With Blankets\Hold Breath\frames_John McNeil HB_5_fps
# Picking frames: [2, 12, 22, 32, 1] per set
# Expected number of frames: 170 (5FPS * 34s).
#
# Done in 17.184086400000524 seconds.
#
# Set counter: 34, save counter: 170, frame counter: 1428
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\2 Meters\With Blankets\Relaxed\frames_John McNeil_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 160 (5FPS * 32s).
#
# Done in 15.928476299999602 seconds.
#
# Set counter: 32, save counter: 160, frame counter: 1408
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\2 Meters\Without Blankets\Hold Breath\frames_John McNeil HB_5_fps
# Picking frames: [2, 13, 23, 34, 1] per set
# Expected number of frames: 165 (5FPS * 33s).
#
# Done in 16.008501799999067 seconds.
#
# Set counter: 33, save counter: 165, frame counter: 1485
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\2 Meters\Without Blankets\Relaxed\frames_John McNeil_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 175 (5FPS * 35s).
#
# Done in 17.029777800002194 seconds.
#
# Set counter: 35, save counter: 175, frame counter: 1540
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\3 Meters\With Blankets\Hold Breath\frames_John McNeil HB_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 160 (5FPS * 32s).
#
# Done in 16.596124400002736 seconds.
#
# Set counter: 32, save counter: 160, frame counter: 1600
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\3 Meters\With Blankets\Relaxed\frames_John McNeil_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 160 (5FPS * 32s).
#
# Done in 16.770653100000345 seconds.
#
# Set counter: 32, save counter: 160, frame counter: 1600
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\3 Meters\Without Blankets\Hold Breath\frames_John McNeil HB_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 185 (5FPS * 37s).
#
# Done in 17.778460800000175 seconds.
#
# Set counter: 37, save counter: 185, frame counter: 1628
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/John McNeil\3 Meters\Without Blankets\Relaxed\frames_John McNeil_5_fps
# Picking frames: [2, 13, 24, 35, 1] per set
# Expected number of frames: 175 (5FPS * 35s).
#
# Done in 17.31469350000043 seconds.
#
# Set counter: 35, save counter: 175, frame counter: 1610
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Joseph\2 Meters\With Blankets\Hold Breath\frames_Joseph HB_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.731916699998692 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1400
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Joseph\2 Meters\With Blankets\Relaxed\frames_Joseph_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 145 (5FPS * 29s).
#
# Done in 15.563380399999005 seconds.
#
# Set counter: 29, save counter: 145, frame counter: 1450
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Joseph\2 Meters\Without Blankets\Hold Breath\frames_Joseph HB_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.877063699997962 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1484
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Joseph\2 Meters\Without Blankets\Relaxed\frames_Joseph_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.134203900001012 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1456
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\2 Meters\With Blankets\Hold Breath\frames_Karlii HB_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 260 (5FPS * 52s).
#
# Done in 27.268112399997335 seconds.
#
# Set counter: 52, save counter: 260, frame counter: 2652
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\2 Meters\With Blankets\Relaxed\frames_Karlii_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 260 (5FPS * 52s).
#
# Done in 27.2726053999977 seconds.
#
# Set counter: 52, save counter: 260, frame counter: 2600
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\2 Meters\Without Blankets\Hold Breath\frames_Karlii HB_5_fps
# Picking frames: [2, 15, 27, 40, 1] per set
# Expected number of frames: 245 (5FPS * 49s).
#
# Done in 26.409556700000394 seconds.
#
# Set counter: 49, save counter: 245, frame counter: 2597
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\2 Meters\Without Blankets\Relaxed\frames_Karlii_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 235 (5FPS * 47s).
#
# Done in 25.79908780000187 seconds.
#
# Set counter: 47, save counter: 235, frame counter: 2585
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\3 Meters\With Blankets\Hold Breath\frames_Karlii HB_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 170 (5FPS * 34s).
#
# Done in 16.643635399999766 seconds.
#
# Set counter: 34, save counter: 170, frame counter: 1496
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\3 Meters\With Blankets\Relaxed\frames_Karlii_5_fps
# Picking frames: [2, 13, 23, 33, 1] per set
# Expected number of frames: 170 (5FPS * 34s).
#
# Done in 16.66342319999967 seconds.
#
# Set counter: 34, save counter: 170, frame counter: 1496
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\3 Meters\Without Blankets\Hold Breath\frames_Karlii HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 285 (5FPS * 57s).
#
# Done in 30.186127100001613 seconds.
#
# Set counter: 57, save counter: 285, frame counter: 2964
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Karlii\3 Meters\Without Blankets\Relaxed\frames_Karlii_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 280 (5FPS * 56s).
#
# Done in 28.297350699998788 seconds.
#
# Set counter: 56, save counter: 280, frame counter: 2800
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\2 Meters\Without Blankets\Hold Breath\frames_Kate_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 105 (5FPS * 21s).
#
# Done in 11.909819500000594 seconds.
#
# Set counter: 21, save counter: 105, frame counter: 1260
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\2 Meters\Without Blankets\Relaxed\frames_Kate_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 95 (5FPS * 19s).
#
# Done in 10.364999699999316 seconds.
#
# Set counter: 19, save counter: 95, frame counter: 1140
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\3 Meters\With Blankets\Hold Breath\frames_Kate HB_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 90 (5FPS * 18s).
#
# Done in 9.898202200001833 seconds.
#
# Set counter: 18, save counter: 90, frame counter: 1080
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\3 Meters\With Blankets\Relaxed\frames_Kate Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 100 (5FPS * 20s).
#
# Done in 10.989227399997617 seconds.
#
# Set counter: 20, save counter: 100, frame counter: 1200
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\3 Meters\Without Blankets\Hold Breath\frames_Kate_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 95 (5FPS * 19s).
#
# Done in 10.311930199997732 seconds.
#
# Set counter: 19, save counter: 95, frame counter: 1140
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Kate\3 Meters\Without Blankets\Relaxed\frames_Kate Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 95 (5FPS * 19s).
#
# Done in 10.485463099998015 seconds.
#
# Set counter: 19, save counter: 95, frame counter: 1140
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\2 Meters\With Blankets\Hold Breath\frames_Krystyn HB_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 13.789020099997288 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1404
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\2 Meters\With Blankets\Relaxed\frames_Krystyn_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 125 (5FPS * 25s).
#
# Done in 13.508560000002035 seconds.
#
# Set counter: 25, save counter: 125, frame counter: 1375
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\2 Meters\Without Blankets\Hold Breath\frames_Krystyn HB_5_fps
# Picking frames: [2, 13, 25, 37, 1] per set
# Expected number of frames: 160 (5FPS * 32s).
#
# Done in 15.673175600000832 seconds.
#
# Set counter: 32, save counter: 160, frame counter: 1536
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\2 Meters\Without Blankets\Relaxed\frames_Krystyn_5_fps
# Picking frames: [2, 14, 25, 37, 1] per set
# Expected number of frames: 155 (5FPS * 31s).
#
# Done in 15.904738199998974 seconds.
#
# Set counter: 31, save counter: 155, frame counter: 1519
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\3 Meters\With Blankets\Hold Breath\frames_Krystyn HB_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 190 (5FPS * 38s).
#
# Done in 18.79914789999748 seconds.
#
# Set counter: 38, save counter: 190, frame counter: 1634
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\3 Meters\With Blankets\Relaxed\frames_Krystyn_5_fps
# Picking frames: [2, 15, 29, 43, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.292070600000443 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1512
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\3 Meters\Without Blankets\Hold Breath\frames_Krystyn HB_5_fps
# Picking frames: [2, 15, 29, 43, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.552176999997755 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1512
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Krystyn\3 Meters\Without Blankets\Relaxed\frames_Krystyn_5_fps
# Picking frames: [2, 16, 29, 43, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 15.031104499998037 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1596
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\2 Meters\With Blankets\Hold Breath\frames_Melissa HB_5_fps
# Picking frames: [2, 15, 28, 41, 1] per set
# Expected number of frames: 230 (5FPS * 46s).
#
# Done in 25.381251599999814 seconds.
#
# Set counter: 46, save counter: 230, frame counter: 2484
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\2 Meters\With Blankets\Relaxed\frames_Melissa_5_fps
# Picking frames: [2, 15, 29, 42, 1] per set
# Expected number of frames: 320 (5FPS * 64s).
#
# Done in 35.75615779999862 seconds.
#
# Set counter: 64, save counter: 320, frame counter: 3520
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\2 Meters\Without Blankets\Hold Breath\frames_Melissa HB_5_fps
# Picking frames: [2, 13, 25, 37, 1] per set
# Expected number of frames: 290 (5FPS * 58s).
#
# Done in 29.3801678000018 seconds.
#
# Set counter: 58, save counter: 290, frame counter: 2784
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\2 Meters\Without Blankets\Relaxed\frames_Melissa_5_fps
# Picking frames: [2, 13, 24, 35, 1] per set
# Expected number of frames: 335 (5FPS * 67s).
#
# Done in 33.59022280000136 seconds.
#
# Set counter: 67, save counter: 335, frame counter: 3082
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\3 Meters\With Blankets\Hold Breath\frames_Melissa HB_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 255 (5FPS * 51s).
#
# Done in 26.83888080000179 seconds.
#
# Set counter: 51, save counter: 255, frame counter: 2601
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\3 Meters\With Blankets\Relaxed\frames_Melissa_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 270 (5FPS * 54s).
#
# Done in 28.368492599998717 seconds.
#
# Set counter: 54, save counter: 270, frame counter: 2808
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\3 Meters\Without Blankets\Hold Breath\frames_Melissa HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 265 (5FPS * 53s).
#
# Done in 27.94426829999793 seconds.
#
# Set counter: 53, save counter: 265, frame counter: 2756
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Melissa\3 Meters\Without Blankets\Relaxed\frames_Melissa_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 240 (5FPS * 48s).
#
# Done in 25.03843330000018 seconds.
#
# Set counter: 48, save counter: 240, frame counter: 2496
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\2 Meters\With Blankets\Hold Breath\frames_Nick HB_5_fps
# Picking frames: [2, 11, 20, 29, 1] per set
# Expected number of frames: 175 (5FPS * 35s).
#
# Done in 17.682921699997678 seconds.
#
# Set counter: 35, save counter: 175, frame counter: 1330
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\2 Meters\With Blankets\Relaxed\frames_Nick_5_fps
# Picking frames: [2, 11, 21, 31, 1] per set
# Expected number of frames: 125 (5FPS * 25s).
#
# Done in 13.085309800000687 seconds.
#
# Set counter: 25, save counter: 125, frame counter: 1000
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\2 Meters\Without Blankets\Hold Breath\frames_Nick HB_5_fps
# Picking frames: [2, 11, 21, 31, 1] per set
# Expected number of frames: 105 (5FPS * 21s).
#
# Done in 10.705805800000235 seconds.
#
# Set counter: 21, save counter: 105, frame counter: 840
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\2 Meters\Without Blankets\Relaxed\frames_n1_5_fps
# Picking frames: [2, 10, 18, 26, 1] per set
# Expected number of frames: 25 (5FPS * 5s).
#
# Done in 2.4352386999999 seconds.
#
# Set counter: 5, save counter: 25, frame counter: 170
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\2 Meters\Without Blankets\Relaxed\frames_Nick_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 175 (5FPS * 35s).
#
# Done in 19.809899399999267 seconds.
#
# Set counter: 35, save counter: 175, frame counter: 2100
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\3 Meters\With Blankets\Hold Breath\frames_Nick HB_5_fps
# Picking frames: [2, 14, 27, 39, 1] per set
# Expected number of frames: 125 (5FPS * 25s).
#
# Done in 13.497517299998435 seconds.
#
# Set counter: 25, save counter: 125, frame counter: 1275
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\3 Meters\With Blankets\Relaxed\frames_Nick_5_fps
# Picking frames: [2, 13, 25, 36, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 12.778632599998673 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1128
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\3 Meters\Without Blankets\Hold Breath\frames_Nick HB_5_fps
# Picking frames: [2, 13, 25, 37, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 12.806271400000696 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1152
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Nick\3 Meters\Without Blankets\Relaxed\frames_Nick_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.426576300000306 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1204
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Rachael B\2 Meters\Without Blankets\Hold Breathe\frames_Rechael Hold Breathe_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 12.986515399999917 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1440
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Rachael B\2 Meters\Without Blankets\Hold Breathe\frames_Rechael Hold Breathe2_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 55 (5FPS * 11s).
#
# Done in 5.63800270000138 seconds.
#
# Set counter: 11, save counter: 55, frame counter: 660
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Rachael B\2 Meters\Without Blankets\Relaxed\frames_Rachael Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 50 (5FPS * 10s).
#
# Done in 5.476277099998697 seconds.
#
# Set counter: 10, save counter: 50, frame counter: 600
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Rachael B\2 Meters\Without Blankets\Relaxed\frames_Rachael Relaxed1_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 60 (5FPS * 12s).
#
# Done in 6.589004199999181 seconds.
#
# Set counter: 12, save counter: 60, frame counter: 720
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Rachael B\2 Meters\Without Blankets\Relaxed\frames_Rachael Relaxed2_5_fps
# Picking frames: [2, 11, 19, 27, 1] per set
# Expected number of frames: 160 (5FPS * 32s).
#
# Done in 14.680413599999156 seconds.
#
# Set counter: 32, save counter: 160, frame counter: 1152
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Riyan\2 Meters\With Blankets\Hold Breath\frames_Riyan HB_5_fps
# Picking frames: [2, 12, 23, 33, 1] per set
# Expected number of frames: 140 (5FPS * 28s).
#
# Done in 14.097594000002573 seconds.
#
# Set counter: 28, save counter: 140, frame counter: 1204
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Riyan\2 Meters\With Blankets\Relaxed\frames_Riyan_5_fps
# Picking frames: [2, 13, 24, 35, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.187066999998933 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1242
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Riyan\2 Meters\Without Blankets\Hold Breath\frames_Riyan HB_5_fps
# Picking frames: [2, 15, 27, 39, 1] per set
# Expected number of frames: 135 (5FPS * 27s).
#
# Done in 14.149500499999704 seconds.
#
# Set counter: 27, save counter: 135, frame counter: 1404
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Riyan\2 Meters\Without Blankets\Relaxed\frames_Riyan_5_fps
# Picking frames: [2, 14, 26, 38, 1] per set
# Expected number of frames: 20 (5FPS * 4s).
#
# Done in 2.052238000000216 seconds.
#
# Set counter: 4, save counter: 20, frame counter: 200
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\2 Meters\With Blankets\Hold Breath\frames_Sara HB_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 110 (5FPS * 22s).
#
# Done in 11.925380700002279 seconds.
#
# Set counter: 22, save counter: 110, frame counter: 1320
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\2 Meters\With Blankets\Relaxed\frames_Sara Relaxed with Blanket_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 13.501366600001347 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1440
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\2 Meters\Without Blankets\Hold Breath\frames_Sara Hold Breath_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 130 (5FPS * 26s).
#
# Done in 14.13327980000031 seconds.
#
# Set counter: 26, save counter: 130, frame counter: 1560
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\2 Meters\Without Blankets\Relaxed\frames_Sara Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 120 (5FPS * 24s).
#
# Done in 13.473953100001381 seconds.
#
# Set counter: 24, save counter: 120, frame counter: 1440
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\3 Meters\With Blankets\Hold Breath\frames_Sara HB_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 100 (5FPS * 20s).
#
# Done in 11.332472699999926 seconds.
#
# Set counter: 20, save counter: 100, frame counter: 1200
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\3 Meters\With Blankets\Relaxed\frames_Sara Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 100 (5FPS * 20s).
#
# Done in 11.247506700001395 seconds.
#
# Set counter: 20, save counter: 100, frame counter: 1200
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\3 Meters\Without Blankets\Hold Breath\frames_Sara HB_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 105 (5FPS * 21s).
#
# Done in 11.985415999999532 seconds.
#
# Set counter: 21, save counter: 105, frame counter: 1260
#
# --------------------------------------------------
#
# Saving frames to: D:/DI_centre_structured/DI_CAMERA_P3225/Final/Sara\3 Meters\Without Blankets\Relaxed\frames_Sara Relaxed_5_fps
# Picking frames: [2, 17, 31, 45, 1] per set
# Expected number of frames: 95 (5FPS * 19s).
#
# Done in 10.047562499999913 seconds.
#
# Set counter: 19, save counter: 95, frame counter: 1140
#
# --------------------------------------------------

# %%
# """ convert video to png (thermal) """

# for level, new_fps in thermal_fps.items():
#     print(f"\nAdjusting FPS to {new_fps}\n" + "="*50)
#     thermal_logfile = thermal_logfile_prefix + "-" + level + ".log"
#     visited_folders = convert_video_to_frame(metadata_thermal, level, new_fps, user_drive)
#     save_folder(visited_folders, thermal_logfile)
